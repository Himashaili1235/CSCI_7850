png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1720.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1721.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1722.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1723.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1724.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1725.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1726.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1727.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1728.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1729.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-173.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1730.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1731.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1732.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1733.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1734.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1735.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1736.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1737.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1738.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1739.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-174.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1740.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1741.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1742.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1743.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1744.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1745.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1746.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1747.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1748.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1749.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-175.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1750.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1751.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1752.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1753.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1754.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1755.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1756.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1757.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1758.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1759.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-176.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1760.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1761.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1762.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1763.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1764.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1765.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1766.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1767.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1768.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1769.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-177.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1770.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1771.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1772.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1773.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1774.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1775.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1776.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1777.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1778.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1779.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-178.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1780.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1781.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1782.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1783.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1784.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1785.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1786.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1787.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1788.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1789.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-179.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1790.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1791.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1792.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1793.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1794.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1795.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1796.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1797.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1798.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1799.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-18.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-180.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1800.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1801.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1802.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1803.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1804.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1805.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1806.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1807.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1808.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1809.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-181.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1810.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1811.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1812.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1813.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1814.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1815.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1816.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1817.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1818.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1819.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-182.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1820.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1821.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1822.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1823.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1824.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1825.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1826.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1827.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1828.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1829.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-183.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1830.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1831.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1832.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1833.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1834.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1835.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1836.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1837.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1838.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1839.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-184.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1840.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1841.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1842.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1843.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1844.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1845.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1846.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1847.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1848.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1849.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-185.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1850.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1851.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1852.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1853.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1854.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1855.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1856.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1857.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1858.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1859.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-186.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1860.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1861.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1862.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1863.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1864.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1865.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1866.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1867.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1868.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1869.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-187.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1870.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1871.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1872.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1873.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1874.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1875.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1876.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1877.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1878.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1879.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-188.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1880.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1881.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1882.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1883.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1884.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1885.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1886.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1887.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1888.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1889.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-189.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1890.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1891.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1892.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1893.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1894.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1895.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1896.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1897.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1898.png',
#  'dataset2\\Bacterial_Pnemonia\\Lung_Opacity-1899.png',
#  ...]

# %%
labels = list(map(lambda x: os.path.split(os.path.split(x)[0])[1], filepaths))
labels
# Out:
# ['Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  'Bacterial_Pnemonia',
#  ...]

# %%
filepath = pd.Series(filepaths, name='Filepath').astype(str)
labels = pd.Series(labels, name='Label')
data = pd.concat([filepath, labels], axis=1)
data = data.sample(frac=1).reset_index(drop=True)
data.head(5)
# Out:
#                                             Filepath               Label
# 0  dataset2\Viral _Pneumonia\Viral Pneumonia-435.png    Viral _Pneumonia
# 1  dataset2\Bacterial_Pnemonia\Lung_Opacity-1223.png  Bacterial_Pnemonia
# 2                     dataset2\Normal\Normal-797.png              Normal
# 3  dataset2\Bacterial_Pnemonia\Lung_Opacity-1953.png  Bacterial_Pnemonia
# 4                     dataset2\Normal\Normal-343.png              Normal

# %%
counts = data.Label.value_counts()
sns.barplot(x=counts.index, y=counts)
plt.xlabel('Type')
plt.xticks(rotation=90);

# %%
from sklearn.model_selection import train_test_split

# %%
train, test = train_test_split(data, test_size=0.25, random_state=42)

# %%
fig, axes = plt.subplots(nrows=5, ncols=3, figsize=(10,8), subplot_kw={'xticks':[],'yticks':[]})
for i, ax in enumerate(axes.flat):
    ax.imshow(plt.imread(data.Filepath[i]))
    ax.set_title(data.Label[i])
plt.tight_layout()
plt.show()

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.callbacks import Callback,EarlyStopping
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.applications.resnet50 import preprocess_input
from sklearn.metrics import  classification_report

# %%
train_datagen = ImageDataGenerator(preprocessing_function=preprocess_input,
                                  validation_split=0.2)
test_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)

# %%
train_gen = train_datagen.flow_from_dataframe(
    dataframe=train,
    x_col='Filepath',
    y_col='Label',
    target_size=(100,100),
    class_mode='categorical',
    batch_size=32,
    shuffle=True,
    seed=42
)
valid_gen = train_datagen.flow_from_dataframe(
    dataframe=test,
    x_col='Filepath',
    y_col='Label',
    target_size=(100,100),
    class_mode='categorical',
    batch_size=32,
    shuffle=False,
    seed=42
)
test_gen = test_datagen.flow_from_dataframe(
    dataframe=test,
    x_col='Filepath',
    y_col='Label',
    target_size=(100,100),
    class_mode='categorical',
    batch_size=32,
    shuffle=False
)
# Out:
# Found 3984 validated image filenames belonging to 3 classes.
# Found 1329 validated image filenames belonging to 3 classes.
# Found 1329 validated image filenames belonging to 3 classes.

# %%
from tensorflow.keras.applications import VGG16
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from tensorflow.keras.models import Model


# Define the input shape
input_shape = (100, 100, 3)

# Specify the path to your locally downloaded weights file
weights_path = 'vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5'

# Create ResNet50 model without top layers and load weights from the local path
pretrained_model = VGG16(
    input_shape=input_shape,
    include_top=False,
    weights=None  # Weights will be loaded manually
)

# Load the weights from your local path
pretrained_model.load_weights(weights_path)

# Set all layers in the model as not trainable
for layer in pretrained_model.layers:
    layer.trainable = False

# Add custom dense layers
x = GlobalAveragePooling2D()(pretrained_model.output)
x = Dense(128, activation='relu')(x)
x = Dense(128, activation='relu')(x)

# Output layer
outputs = Dense(3, activation='softmax')(x)  # Assuming 3 classes, replace with your actual number of classes

# Create the updated model
model = Model(inputs=pretrained_model.input, outputs=outputs)

# %%
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %%
my_callbacks  = [EarlyStopping(monitor='val_accuracy',
                              min_delta=0,
                              patience=2,
                              mode='auto')]

# %%
history = model.fit(
    train_gen,
    validation_data=valid_gen,
    epochs=30,
)
# Out:
# Epoch 1/30
# 125/125 [==============================] - 221s 2s/step - loss: 0.1331 - accuracy: 0.9490 - val_loss: 0.3022 - val_accuracy: 0.8947
# Epoch 2/30
# 125/125 [==============================] - 139s 1s/step - loss: 0.1037 - accuracy: 0.9578 - val_loss: 0.2819 - val_accuracy: 0.8977
# Epoch 3/30
# 125/125 [==============================] - 141s 1s/step - loss: 0.0762 - accuracy: 0.9729 - val_loss: 0.3707 - val_accuracy: 0.8939
# Epoch 4/30
# 125/125 [==============================] - 231s 2s/step - loss: 0.0684 - accuracy: 0.9757 - val_loss: 0.3235 - val_accuracy: 0.9029
# Epoch 5/30
# 125/125 [==============================] - 158s 1s/step - loss: 0.0515 - accuracy: 0.9847 - val_loss: 0.4926 - val_accuracy: 0.8653
# Epoch 6/30
# 125/125 [==============================] - 140s 1s/step - loss: 0.0642 - accuracy: 0.9759 - val_loss: 0.4299 - val_accuracy: 0.8879
# Epoch 7/30
# 125/125 [==============================] - 145s 1s/step - loss: 0.0488 - accuracy: 0.9842 - val_loss: 0.3791 - val_accuracy: 0.8969
# Epoch 8/30
# 125/125 [==============================] - 146s 1s/step - loss: 0.0523 - accuracy: 0.9814 - val_loss: 0.3582 - val_accuracy: 0.9029
# Epoch 9/30
# 125/125 [==============================] - 143s 1s/step - loss: 0.0282 - accuracy: 0.9907 - val_loss: 0.4030 - val_accuracy: 0.8962
# Epoch 10/30
# 125/125 [==============================] - 150s 1s/step - loss: 0.0211 - accuracy: 0.9927 - val_loss: 0.3835 - val_accuracy: 0.9067
# Epoch 11/30
# 125/125 [==============================] - 132s 1s/step - loss: 0.0274 - accuracy: 0.9915 - val_loss: 0.4258 - val_accuracy: 0.9052
# Epoch 12/30
# 125/125 [==============================] - 140s 1s/step - loss: 0.0133 - accuracy: 0.9970 - val_loss: 0.4324 - val_accuracy: 0.9059
# Epoch 13/30
# 125/125 [==============================] - 133s 1s/step - loss: 0.0029 - accuracy: 0.9997 - val_loss: 0.4614 - val_accuracy: 0.9044
# Epoch 14/30
# 125/125 [==============================] - 129s 1s/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.4613 - val_accuracy: 0.9067
# Epoch 15/30
# 125/125 [==============================] - 126s 1s/step - loss: 8.6277e-04 - accuracy: 1.0000 - val_loss: 0.4729 - val_accuracy: 0.9067
# Epoch 16/30
# 125/125 [==============================] - 125s 1000ms/step - loss: 6.8435e-04 - accuracy: 1.0000 - val_loss: 0.4862 - val_accuracy: 0.9082
# Epoch 17/30
# 125/125 [==============================] - 128s 1s/step - loss: 5.7059e-04 - accuracy: 1.0000 - val_loss: 0.4949 - val_accuracy: 0.9074
# Epoch 18/30
# 125/125 [==============================] - 127s 1s/step - loss: 4.6199e-04 - accuracy: 1.0000 - val_loss: 0.5023 - val_accuracy: 0.9059
# Epoch 19/30
# 125/125 [==============================] - 127s 1s/step - loss: 4.1111e-04 - accuracy: 1.0000 - val_loss: 0.5129 - val_accuracy: 0.9067
# Epoch 20/30
# 125/125 [==============================] - 124s 991ms/step - loss: 3.5539e-04 - accuracy: 1.0000 - val_loss: 0.5170 - val_accuracy: 0.9052
# Epoch 21/30
# 125/125 [==============================] - 125s 1000ms/step - loss: 3.2542e-04 - accuracy: 1.0000 - val_loss: 0.5252 - val_accuracy: 0.9067
# Epoch 22/30
# 125/125 [==============================] - 127s 1s/step - loss: 2.8617e-04 - accuracy: 1.0000 - val_loss: 0.5324 - val_accuracy: 0.9059
# Epoch 23/30
# 125/125 [==============================] - 126s 1s/step - loss: 2.5272e-04 - accuracy: 1.0000 - val_loss: 0.5389 - val_accuracy: 0.9067
# Epoch 24/30
# 125/125 [==============================] - 120s 958ms/step - loss: 2.3303e-04 - accuracy: 1.0000 - val_loss: 0.5503 - val_accuracy: 0.9059
# Epoch 25/30
# 125/125 [==============================] - 115s 923ms/step - loss: 2.0608e-04 - accuracy: 1.0000 - val_loss: 0.5517 - val_accuracy: 0.9067
# Epoch 26/30
# 125/125 [==============================] - 116s 930ms/step - loss: 1.8697e-04 - accuracy: 1.0000 - val_loss: 0.5588 - val_accuracy: 0.9067
# Epoch 27/30
# 125/125 [==============================] - 126s 1s/step - loss: 1.7120e-04 - accuracy: 1.0000 - val_loss: 0.5615 - val_accuracy: 0.9067
# Epoch 28/30
# 125/125 [==============================] - 124s 993ms/step - loss: 1.5345e-04 - accuracy: 1.0000 - val_loss: 0.5704 - val_accuracy: 0.9074
# Epoch 29/30
# 125/125 [==============================] - 126s 1s/step - loss: 1.4134e-04 - accuracy: 1.0000 - val_loss: 0.5747 - val_accuracy: 0.9074
# Epoch 30/30
# 125/125 [==============================] - 124s 991ms/step - loss: 1.2820e-04 - accuracy: 1.0000 - val_loss: 0.5793 - val_accuracy: 0.9067

# %%
model.save("model_vgg16.h5")

# %%
pd.DataFrame(history.history)[['accuracy','val_accuracy']].plot()
plt.title("Accuracy")
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.show()

pd.DataFrame(history.history)[['loss','val_loss']].plot()
plt.title("Loss")
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.show()

# %%
results = model.evaluate(test_gen, verbose=0)

print("    Test Loss: {:.5f}".format(results[0]))
print("Test Accuracy: {:.2f}%".format(results[1] * 100))
# Out:
#     Test Loss: 0.57932
# Test Accuracy: 90.67%

# %%
# Predict the label of the test_gen
pred = model.predict(test_gen)
pred = np.argmax(pred,axis=1)

# Map the label
labels = (train_gen.class_indices)
labels = dict((v,k) for k,v in labels.items())
pred = [labels[k] for k in pred]

# %%
y_test = list(test.Label)
print(classification_report(y_test, pred))
# Out:
#                     precision    recall  f1-score   support
#
# Bacterial_Pnemonia       0.36      0.37      0.36       482
#             Normal       0.36      0.34      0.35       504
#   Viral _Pneumonia       0.25      0.25      0.25       343
#
#           accuracy                           0.33      1329
#          macro avg       0.32      0.32      0.32      1329
#       weighted avg       0.33      0.33      0.33      1329

# %%
fig, axes = plt.subplots(nrows=5, ncols=2, figsize=(12, 8),
                        subplot_kw={'xticks': [], 'yticks': []})

for i, ax in enumerate(axes.flat):
    ax.imshow(plt.imread(test.Filepath.iloc[i]))
    ax.set_title(f"True: {test.Label.iloc[i]}\nPredicted: {pred[i]}")
plt.tight_layout()
plt.show()

# %%
import cv2
import numpy as np
from matplotlib.pyplot import imread
from matplotlib.pyplot import imshow
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.imagenet_utils import decode_predictions
from tensorflow.keras.applications.imagenet_utils import preprocess_input

img_path = 'Lung_Opacity-29.png'

#img = image.load_img(img_path, target_size=(224, 224))
#x = img.img_to_array(img)

img = cv2.imread(img_path)
img = cv2.resize(img, (100, 100))

x = np.expand_dims(img, axis=0)
x = preprocess_input(x)
result = model.predict(x)
print((result*100).astype('int'))

#print('Input image shape:', x.shape)

#my_image = imread(img_path)
#imshow(my_image)
# Define your labels
labels = ["bacterial_pneumonia", "normal", "viral_pneumonia"]

# Find the index with the highest percentage
max_index = np.argmax((result*100).astype('int'))

# Print the corresponding label
print("Predicted Label:", labels[max_index])
# Out:
# [[ 1 98  0]]
# Predicted Label: normal
